# %% [markdown]
# ![1.PNG](data:image/png;base64,...)

# %%
c = 2
for i in range(1 , 6) :
  print('* ' * i)
for i in range(4 , 0 , -1) :
  print('* ' * i)
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %% [markdown]
# ![2.PNG](data:image/png;base64,...)

# %%
ip = input('Input Word : ')
print('Output : ' + ip[::-1])
# Out:
# Input Word : ineuron
# Output : norueni
